# %% [markdown]
# # ETL

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# Carregando datasets

# %%
veiculos = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/veiculos.csv")

# %%
rotas = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/rotas.csv")

# %%
entregas = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/entregas.csv")

# %%
manutencao = pd.read_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/manutencao.csv")

# %% [markdown]
# # Veiculos

# %%
veiculos.head()
# Out:
#    Número_caminhao     marca                            Ano  Km_rodados  \
# 0             1001    Scania  2023-12-21 17:13:03.684174464      276675
# 1             1002     Volvo  2023-04-23 06:43:39.735883136       61358
# 2             1003    Scania  2015-10-19 08:07:16.239027664      531097
# 3             1004  Mercedes  2012-08-24 04:39:10.018144392      692274
# 4             1005     Volvo  2017-07-10 20:37:34.525778720      564678
#
#          tipo
# 0  articulado
# 1  articulado
# 2      rígido
# 3      rígido
# 4  articulado

# %%
veiculos.tail()
# Out:
#     Número_caminhao     marca                            Ano  Km_rodados  \
# 95             1096     Volvo  2015-11-19 00:42:40.658100176      554298
# 96             1097    Scania  2020-03-13 13:01:18.227046976       86630
# 97             1098     Volvo  2017-05-17 11:43:52.253323296      307517
# 98             1099  Mercedes  2013-05-08 17:09:48.751715504      678785
# 99            10100    Scania  2018-06-03 04:02:52.473119552      502073
#
#           tipo
# 95      rígido
# 96      rígido
# 97  articulado
# 98      rígido
# 99  articulado

# %% [markdown]
# Visualizando estrutra do dataset

# %%
veiculos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Número_caminhao  100 non-null    int64
#  1   marca            100 non-null    object
#  2   Ano              100 non-null    object
#  3   Km_rodados       100 non-null    int64
#  4   tipo             100 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
veiculos.isnull().sum()
# Out:
# Número_caminhao    0
# marca              0
# Ano                0
# Km_rodados         0
# tipo               0
# dtype: int64

# %%
veiculos.duplicated().sum()
# Out:
# 0

# %%
veiculos['Número_caminhao'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Corrigindo coluna ano

# %%
veiculos['Ano'] = pd.to_datetime(veiculos['Ano']).dt.date

# %%
veiculos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Número_caminhao  100 non-null    int64
#  1   marca            100 non-null    object
#  2   Ano              100 non-null    object
#  3   Km_rodados       100 non-null    int64
#  4   tipo             100 non-null    object
# dtypes: int64(2), object(3)
# memory usage: 4.0+ KB

# %%
veiculos.head()
# Out:
#    Número_caminhao     marca         Ano  Km_rodados        tipo
# 0             1001    Scania  2023-12-21      276675  articulado
# 1             1002     Volvo  2023-04-23       61358  articulado
# 2             1003    Scania  2015-10-19      531097      rígido
# 3             1004  Mercedes  2012-08-24      692274      rígido
# 4             1005     Volvo  2017-07-10      564678  articulado

# %%
veiculos['Ano'] = pd.to_datetime(veiculos['Ano'])

# %%
veiculos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Número_caminhao  100 non-null    int64
#  1   marca            100 non-null    object
#  2   Ano              100 non-null    datetime64[ns]
#  3   Km_rodados       100 non-null    int64
#  4   tipo             100 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 4.0+ KB

# %% [markdown]
# Verificando outliers

# %%
sns.boxplot(data=veiculos, x='Km_rodados')
# Out:
# <Axes: xlabel='Km_rodados'>

# %%
veiculos['Km_rodados'].describe()
# Out:
# count       100.000000
# mean     440307.610000
# std      230192.164358
# min       61358.000000
# 25%      259550.750000
# 50%      431093.000000
# 75%      567749.250000
# max      898371.000000
# Name: Km_rodados, dtype: float64

# %%
veiculos.to_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/veiculos-v1.csv")

# %% [markdown]
# # Dataset rotas

# %%
rotas.head()
# Out:
#    Unnamed: 0  Número_Caminhão                rotas  Distância_km  \
# 0           0             1001   Uberlândia-Catalão           190
# 1           1             1002  Uberlândia-Araguari            30
# 2           2             1003   Uberlândia-Uberaba           110
# 3           3             1004   Uberlândia-Goiânia           330
# 4           4             1005  Uberlândia-Araguari            30
#
#    Tempo_estimado_horas Tipo_De_Carga Frequência
# 0                 2.375       consumo     díaria
# 1                 0.375    industrial     díaria
# 2                 1.375       consumo     mensal
# 3                 4.125      agrícola     díaria
# 4                 0.375      agrícola     díaria

# %%
rotas.tail()
# Out:
#     Unnamed: 0  Número_Caminhão                      rotas  Distância_km  \
# 95          95             1096  Uberlândia-Ribeirão_Preto           300
# 96          96             1097  Uberlândia-Belo_Horizonte           540
# 97          97             1098  Uberlândia-Rio_de_Janeiro           985
# 98          98             1099        Uberlândia-Brasília           430
# 99          99            10100       Uberlândia-São_Paulo           585
#
#     Tempo_estimado_horas Tipo_De_Carga Frequência
# 95                3.7500      agrícola     díaria
# 96                6.7500      agrícola     mensal
# 97               12.3125    industrial     díaria
# 98                5.3750      agrícola     mensal
# 99                7.3125    industrial     mensal

# %% [markdown]
# Verificando estrutura do dataset

# %%
rotas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            100 non-null    int64
#  1   Número_Caminhão       100 non-null    int64
#  2   rotas                 100 non-null    object
#  3   Distância_km          100 non-null    int64
#  4   Tempo_estimado_horas  100 non-null    float64
#  5   Tipo_De_Carga         100 non-null    object
#  6   Frequência            100 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 5.6+ KB

# %% [markdown]
# Arendondando tempo estimado

# %%
rotas['Tempo_estimado_horas'] = rotas['Tempo_estimado_horas'].round(2)

# %%
rotas.head()
# Out:
#    Unnamed: 0  Número_Caminhão                rotas  Distância_km  \
# 0           0             1001   Uberlândia-Catalão           190
# 1           1             1002  Uberlândia-Araguari            30
# 2           2             1003   Uberlândia-Uberaba           110
# 3           3             1004   Uberlândia-Goiânia           330
# 4           4             1005  Uberlândia-Araguari            30
#
#    Tempo_estimado_horas Tipo_De_Carga Frequência
# 0                  2.38       consumo     díaria
# 1                  0.38    industrial     díaria
# 2                  1.38       consumo     mensal
# 3                  4.12      agrícola     díaria
# 4                  0.38      agrícola     díaria

# %%
rotas.tail()
# Out:
#     Unnamed: 0  Número_Caminhão                      rotas  Distância_km  \
# 95          95             1096  Uberlândia-Ribeirão_Preto           300
# 96          96             1097  Uberlândia-Belo_Horizonte           540
# 97          97             1098  Uberlândia-Rio_de_Janeiro           985
# 98          98             1099        Uberlândia-Brasília           430
# 99          99            10100       Uberlândia-São_Paulo           585
#
#     Tempo_estimado_horas Tipo_De_Carga Frequência
# 95                  3.75      agrícola     díaria
# 96                  6.75      agrícola     mensal
# 97                 12.31    industrial     díaria
# 98                  5.38      agrícola     mensal
# 99                  7.31    industrial     mensal

# %% [markdown]
# Verificando Outliers

# %%
sns.boxplot(data=rotas, x='Distância_km')
# Out:
# <Axes: xlabel='Distância_km'>

# %%
rotas['Distância_km'].describe()
# Out:
# count    100.000000
# mean     437.100000
# std      278.196918
# min       30.000000
# 25%      190.000000
# 50%      430.000000
# 75%      585.000000
# max      985.000000
# Name: Distância_km, dtype: float64

# %%
sns.boxplot(data=rotas, x='Tempo_estimado_horas')
# Out:
# <Axes: xlabel='Tempo_estimado_horas'>

# %%
rotas['Tempo_estimado_horas'].describe()
# Out:
# count    100.000000
# mean       5.464700
# std        3.475149
# min        0.380000
# 25%        2.380000
# 50%        5.380000
# 75%        7.310000
# max       12.310000
# Name: Tempo_estimado_horas, dtype: float64
