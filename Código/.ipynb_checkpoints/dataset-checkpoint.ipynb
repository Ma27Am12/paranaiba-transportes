# %% [markdown]
# # Criando dataset da empresa

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Criando identificador dos caminhões.

# %%
ids = [f"10{str(i).zfill(2)}" for i in range(1, 101)]

veiculo = pd.DataFrame({"Número_caminhao": ids})

# %%
veiculo.head()
# Out:
#   Número_caminhao
# 0            1001
# 1            1002
# 2            1003
# 3            1004
# 4            1005

# %%
veiculo.tail()
# Out:
#    Número_caminhao
# 95            1096
# 96            1097
# 97            1098
# 98            1099
# 99           10100

# %% [markdown]
# Verificando o tipo de dado da coluna

# %%
veiculo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Número_caminhao  100 non-null    object
# dtypes: object(1)
# memory usage: 932.0+ bytes

# %%
marcas = ['Scania', 'Mercedes', 'Volvo']
veiculo['marca'] = np.random.choice(marcas, size=len(veiculo))

# %%
veiculo.head()
# Out:
#   Número_caminhao     marca
# 0            1001     Volvo
# 1            1002    Scania
# 2            1003  Mercedes
# 3            1004  Mercedes
# 4            1005    Scania

# %%
veiculo.tail()
# Out:
#    Número_caminhao     marca
# 95            1096     Volvo
# 96            1097  Mercedes
# 97            1098    Scania
# 98            1099  Mercedes
# 99           10100     Volvo

# %%
start = pd.to_datetime("2012-01-01")
end = pd.to_datetime("2023-12-31")

n = len(veiculo)

random_dates = start + (end - start) * np.random.rand(n)

veiculo['Ano'] = random_dates

# %%
veiculo.head()
# Out:
#   Número_caminhao     marca                           Ano
# 0            1001     Volvo 2022-02-13 01:00:05.522827904
# 1            1002    Scania 2018-01-27 22:28:02.666727424
# 2            1003  Mercedes 2015-05-12 09:00:48.671316224
# 3            1004  Mercedes 2014-05-28 14:09:45.142881584
# 4            1005    Scania 2013-09-20 01:26:59.478378488

# %%
veiculo.tail()
# Out:
#    Número_caminhao     marca                           Ano
# 95            1096     Volvo 2015-04-19 03:47:08.670441264
# 96            1097  Mercedes 2014-11-10 01:06:21.743201616
# 97            1098    Scania 2022-06-12 05:24:56.321288832
# 98            1099  Mercedes 2012-03-12 01:40:06.966295046
# 99           10100     Volvo 2013-08-27 07:44:53.242218080

# %%
ano_de_fabricação = pd.to_datetime(veiculo['Ano']).dt.year

# %%
ano_de_fabricação
# Out:
# 0     2022
# 1     2018
# 2     2015
# 3     2014
# 4     2013
#       ...
# 95    2015
# 96    2014
# 97    2022
# 98    2012
# 99    2013
# Name: Ano, Length: 100, dtype: int32

# %%
km = []
for ano in ano_de_fabricação:
    if ano <= 2014:
        km.append(np.random.randint(600000, 900000))
    elif ano <= 2018:
        km.append(np.random.randint(300000, 600000))
    else:
        km.append(np.random.randint(50000, 300000)) 
veiculo['Km_rodados'] = km

# %%
veiculo.head()
# Out:
#   Número_caminhao     marca                           Ano  Km_rodados
# 0            1001     Volvo 2022-02-13 01:00:05.522827904      110496
# 1            1002    Scania 2018-01-27 22:28:02.666727424      346295
# 2            1003  Mercedes 2015-05-12 09:00:48.671316224      442854
# 3            1004  Mercedes 2014-05-28 14:09:45.142881584      715342
# 4            1005    Scania 2013-09-20 01:26:59.478378488      867200

# %%
tipo = ['rígido', 'articulado']

veiculo['tipo'] = np.random.choice(tipo, size=len(veiculo))

# %%
veiculo.head()
# Out:
#   Número_caminhao     marca                           Ano  Km_rodados  \
# 0            1001     Volvo 2022-02-13 01:00:05.522827904      110496
# 1            1002    Scania 2018-01-27 22:28:02.666727424      346295
# 2            1003  Mercedes 2015-05-12 09:00:48.671316224      442854
# 3            1004  Mercedes 2014-05-28 14:09:45.142881584      715342
# 4            1005    Scania 2013-09-20 01:26:59.478378488      867200
#
#          tipo
# 0      rígido
# 1  articulado
# 2      rígido
# 3  articulado
# 4  articulado

# %%
veiculo.to_csv("C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/veiculos.csv", index=False)

# %%
Número_caminhao = veiculo['Número_caminhao']

# %%
rotas_lista = [
    'Uberlândia-São_Paulo',
    'Uberlândia-Belo_Horizonte',
    'Uberlândia-Brasília',
    'Uberlândia-Goiânia',
    'Uberlândia-Rio_de_Janeiro',
    'Uberlândia-Uberaba',
    'Uberlândia-Araguari',
    'Uberlândia-Catalão',
    'Uberlândia-Ribeirão_Preto'
]

# %%
rotas = pd.DataFrame({'Número_Caminhão': Número_caminhao})

# %%
rotas.head()
# Out:
#   Número_Caminhão
# 0            1001
# 1            1002
# 2            1003
# 3            1004
# 4            1005

# %%
rotas['rotas'] = np.random.choice(rotas_lista, size=len(rotas))

# %%
rotas.head()
# Out:
#   Número_Caminhão                      rotas
# 0            1001        Uberlândia-Brasília
# 1            1002         Uberlândia-Catalão
# 2            1003  Uberlândia-Ribeirão_Preto
# 3            1004         Uberlândia-Catalão
# 4            1005        Uberlândia-Araguari

# %%
rotas.tail()
# Out:
#    Número_Caminhão                      rotas
# 95            1096  Uberlândia-Ribeirão_Preto
# 96            1097        Uberlândia-Araguari
# 97            1098  Uberlândia-Rio_de_Janeiro
# 98            1099        Uberlândia-Brasília
# 99           10100  Uberlândia-Ribeirão_Preto

# %%
distancias = {   
    'Uberlândia-São_Paulo':585,
    'Uberlândia-Belo_Horizonte':540,
    'Uberlândia-Brasília':430,
    'Uberlândia-Goiânia':330,
    'Uberlândia-Rio_de_Janeiro':985,
    'Uberlândia-Uberaba':110,
    'Uberlândia-Araguari':30,
    'Uberlândia-Catalão':190,
    'Uberlândia-Ribeirão_Preto': 300
}

# %%
rotas['Distância_km'] = rotas['rotas'].map(distancias)

# %%
rotas.head()
# Out:
#   Número_Caminhão                      rotas  Distância_km
# 0            1001        Uberlândia-Brasília           430
# 1            1002         Uberlândia-Catalão           190
# 2            1003  Uberlândia-Ribeirão_Preto           300
# 3            1004         Uberlândia-Catalão           190
# 4            1005        Uberlândia-Araguari            30

# %%
rotas.tail()
# Out:
#    Número_Caminhão                      rotas  Distância_km
# 95            1096  Uberlândia-Ribeirão_Preto           300
# 96            1097        Uberlândia-Araguari            30
# 97            1098  Uberlândia-Rio_de_Janeiro           985
# 98            1099        Uberlândia-Brasília           430
# 99           10100  Uberlândia-Ribeirão_Preto           300

# %%
velocidade_media = 80
rotas['Tempo_estimado_horas'] = rotas['Distância_km'] / velocidade_media

# %%
rotas.head()
# Out:
#   Número_Caminhão                      rotas  Distância_km  \
# 0            1001        Uberlândia-Brasília           430
# 1            1002         Uberlândia-Catalão           190
# 2            1003  Uberlândia-Ribeirão_Preto           300
# 3            1004         Uberlândia-Catalão           190
# 4            1005        Uberlândia-Araguari            30
#
#    Tempo_estimado_horas
# 0                 5.375
# 1                 2.375
# 2                 3.750
# 3                 2.375
# 4                 0.375

# %%
rotas.tail()
# Out:
#    Número_Caminhão                      rotas  Distância_km  \
# 95            1096  Uberlândia-Ribeirão_Preto           300
# 96            1097        Uberlândia-Araguari            30
# 97            1098  Uberlândia-Rio_de_Janeiro           985
# 98            1099        Uberlândia-Brasília           430
# 99           10100  Uberlândia-Ribeirão_Preto           300
#
#     Tempo_estimado_horas
# 95                3.7500
# 96                0.3750
# 97               12.3125
# 98                5.3750
# 99                3.7500

# %%
tipo_de_carga = ['agrícola', 'industrial', 'consumo']

# %%
rotas['Tipo_De_Carga'] = np.random.choice(tipo_de_carga, size=len(rotas))

# %%
rotas.head()
# Out:
#   Número_Caminhão                      rotas  Distância_km  \
# 0            1001        Uberlândia-Brasília           430
# 1            1002         Uberlândia-Catalão           190
# 2            1003  Uberlândia-Ribeirão_Preto           300
# 3            1004         Uberlândia-Catalão           190
# 4            1005        Uberlândia-Araguari            30
#
#    Tempo_estimado_horas Tipo_De_Carga
# 0                 5.375       consumo
# 1                 2.375       consumo
# 2                 3.750      agrícola
# 3                 2.375    industrial
# 4                 0.375      agrícola

# %%
frequencia = ['díaria', 'semanal', 'mensal']

# %%
rotas['Frequência'] = np.random.choice(frequencia, size=len(rotas))

# %%
rotas.head()
# Out:
#   Número_Caminhão                      rotas  Distância_km  \
# 0            1001        Uberlândia-Brasília           430
# 1            1002         Uberlândia-Catalão           190
# 2            1003  Uberlândia-Ribeirão_Preto           300
# 3            1004         Uberlândia-Catalão           190
# 4            1005        Uberlândia-Araguari            30
#
#    Tempo_estimado_horas Tipo_De_Carga Frequência
# 0                 5.375       consumo     díaria
# 1                 2.375       consumo    semanal
# 2                 3.750      agrícola    semanal
# 3                 2.375    industrial     díaria
# 4                 0.375      agrícola    semanal

# %%
rotas.to_csv('C:/Users/mathe/Documents/projetos/Analise de dados/projeto-20/paranaiba-transportes/dataset/rotas.csv')
