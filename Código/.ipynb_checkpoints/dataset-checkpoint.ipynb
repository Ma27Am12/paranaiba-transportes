# %% [markdown]
# # Criando dataset da empresa

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# Criando identificador dos caminhões.

# %%
ids = [f"10{str(i).zfill(2)}" for i in range(1, 101)]

veiculo = pd.DataFrame({"Número_caminhao": ids})

# %%
veiculo.head()
# Out:
#   Número_caminhao
# 0            1001
# 1            1002
# 2            1003
# 3            1004
# 4            1005

# %%
veiculo.tail()
# Out:
#    Número_caminhao
# 95            1096
# 96            1097
# 97            1098
# 98            1099
# 99           10100

# %% [markdown]
# Verificando o tipo de dado da coluna

# %%
veiculo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 1 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Número_caminhao  100 non-null    object
# dtypes: object(1)
# memory usage: 932.0+ bytes

# %%
veiculo_scania = veiculo[veiculo['Número_caminhao'] <= '1040']
